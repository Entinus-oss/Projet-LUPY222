# %%
# Importation des librairies réunies en une seule cellule, plus pratique
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from scipy.io.wavfile import write, read
import wave
import struct
import IPython.display as ipd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/93/ht7wyk3931g4v1jg73c789m00000gn/T/ipykernel_61005/574008631.py in <module>
#       1 # Importation des librairies réunies en une seule cellule, plus pratique
# ----> 2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 from mpl_toolkits import mplot3d
#       5 from scipy.io.wavfile import write, read
#
# ModuleNotFoundError: No module named 'numpy'

# %%
def visualize_wav(f):

    """Decompose wav file into int16 array. Return a time linspace to plot and the array"""

    framerate, frames = read(f)

    return framerate, frames

framerate, frames = visualize_wav("test.wav")
t_wav = np.arange(0, len(frames)/5)/framerate

plt.figure(figsize = (20,5))

frames1 = frames[ : int(len(frames)/5)]

plt.plot(t_wav, frames1)

plt.show()

# %%
Framerate, Frames = read('reference.wav')

time1 = np.arange(0, 0.2, 1/Framerate)

plt.figure(figsize = (20,5))

Frames1 = Frames[ : int(0.2*framerate1)]

plt.plot(time1, Frames1)

plt.show()

# %%
plt.figure(figsize = (20,5))


plt.plot(time1, abs(frames1 - Frames1))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/93/ht7wyk3931g4v1jg73c789m00000gn/T/ipykernel_61005/767885049.py in <module>
# ----> 1 plt.figure(figsize = (20,5))
#       2
#       3
#       4 plt.plot(time1, abs(frames1 - Frames1))
#       5
#
# NameError: name 'plt' is not defined
